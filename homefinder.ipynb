# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('DC 28.4.22 Homefinder redacted.xlsx',sheet_name='Advertised Properties')
df1.head()
# Out:
#    Advert  Number of Bedrooms  Number of Bedspaces Postcode     Status  Bids  \
# 0       1                   0                    1  CV6 5PU  Withdrawn    75
# 1       2                   1                    2  CV2 1LU        Let    39
# 2       3                   2                    4  CV1 5GX        Let    93
# 3       4                   1                    2  CV2 1ER        Let    17
# 4       5                   3                    6  CV1 5AN        Let   144
#
#    Offers  Refusals  Rejections Status or Let Date  Band  \
# 0       0         0           0         2021-09-29   NaN
# 1       1         0          29         2021-11-19   2.0
# 2       1         0          10         2021-11-26   1.0
# 3       1         0           6         2021-10-26   2.0
# 4       2         1           7         2021-10-28   1.0
#
#                                          Band Reason Offer Date
# 0                                                NaN        NaT
# ...

# %%
df1.head()
# Out:
#    Advert  Number of Bedrooms  Number of Bedspaces Postcode     Status  Bids  \
# 0       1                   0                    1  CV6 5PU  Withdrawn    75
# 1       2                   1                    2  CV2 1LU        Let    39
# 2       3                   2                    4  CV1 5GX        Let    93
# 3       4                   1                    2  CV2 1ER        Let    17
# 4       5                   3                    6  CV1 5AN        Let   144
#
#    Offers  Refusals  Rejections Status or Let Date  Band  \
# 0       0         0           0         2021-09-29   NaN
# 1       1         0          29         2021-11-19   2.0
# 2       1         0          10         2021-11-26   1.0
# 3       1         0           6         2021-10-26   2.0
# 4       2         1           7         2021-10-28   1.0
#
#                                          Band Reason Offer Date
# 0                                                NaN        NaT
# ...

# %% [markdown]
# Assuming adverts are unique properties

# %%
df1.groupby('Status').count()
# Out:
#                     Advert  Number of Bedrooms  Number of Bedspaces  Postcode  \
# Status
# Accepted                 4                   4                    4         4
# Let                    429                 429                  429       429
# Let Outside Locata       5                   5                    5         5
# Offered                116                 116                  116       116
# Open for bids           26                  26                   26        26
# Pending                  3                   3                    3         3
# Re-Advertised            3                   3                    3         3
# Ready to offer         166                 166                  166       166
# Withdrawn              162                 162                  162       162
#
#                     Bids  Offers  Refusals  Rejections  Status or Let Date  \
# Status
# Accepted               4       4         4           4                   4
# ...

# %%
count = df1[['Number of Bedrooms','Bids']].groupby('Number of Bedrooms').sum()

# %%
total = df1['Bids'].sum()
print(total)
# Out:
# 109313

# %%
count['%'] = count['Bids']/total*100

# %%
count
# Out:
#                      Bids          %
# Number of Bedrooms
# 0                    9052   8.280808
# 1                   42499  38.878267
# 2                   29175  26.689415
# 3                   27934  25.554143
# 4                     624   0.570838
# 5                      25   0.022870
# 6                       4   0.003659

# %%
df1[['Number of Bedrooms','Bids']].groupby('Number of Bedrooms').count()
# Out:
#                     Bids
# Number of Bedrooms
# 0                    111
# 1                    374
# 2                    288
# 3                    130
# 4                      9
# 5                      1
# 6                      1
