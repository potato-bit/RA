# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('DC 28.4.22 Homefinder redacted.xlsx',sheet_name='Advertised Properties')
df1.head()
# Out:
#    Advert  Number of Bedrooms  Number of Bedspaces Postcode     Status  Bids  \
# 0       1                   0                    1  CV6 5PU  Withdrawn    75
# 1       2                   1                    2  CV2 1LU        Let    39
# 2       3                   2                    4  CV1 5GX        Let    93
# 3       4                   1                    2  CV2 1ER        Let    17
# 4       5                   3                    6  CV1 5AN        Let   144
#
#    Offers  Refusals  Rejections Status or Let Date  Band  \
# 0       0         0           0         2021-09-29   NaN
# 1       1         0          29         2021-11-19   2.0
# 2       1         0          10         2021-11-26   1.0
# 3       1         0           6         2021-10-26   2.0
# 4       2         1           7         2021-10-28   1.0
#
#                                          Band Reason Offer Date
# 0                                                NaN        NaT
# ...

# %%
columns = ['ad_id','bedrooms','bedspaces','postcode','status','bids','offers','refusals','rejections','date_let','band','band_r','date_offer']
df1.columns = columns

# %%
df1.head()
# Out:
#    ad_id  bedrooms  bedspaces postcode     status  bids  offers  refusals  \
# 0      1         0          1  CV6 5PU  Withdrawn    75       0         0
# 1      2         1          2  CV2 1LU        Let    39       1         0
# 2      3         2          4  CV1 5GX        Let    93       1         0
# 3      4         1          2  CV2 1ER        Let    17       1         0
# 4      5         3          6  CV1 5AN        Let   144       2         1
#
#    rejections   date_let  band  \
# 0           0 2021-09-29   NaN
# 1          29 2021-11-19   2.0
# 2          10 2021-11-26   1.0
# 3           6 2021-10-26   2.0
# 4           7 2021-10-28   1.0
#
#                                               band_r date_offer
# 0                                                NaN        NaT
# 1  People living in named short-term supported ac... 2021-11-10
# 2                            Reduced Preference Band 2021-11-26
# 3  People living in named short-term supported ac... 2021-10-25
# ...

# %% [markdown]
# Assuming adverts are unique properties

# %%
df1[['ad_id','status']].groupby('status').count()
# Out:
#                     ad_id
# status
# Accepted                4
# Let                   429
# Let Outside Locata      5
# Offered               116
# Open for bids          26
# Pending                 3
# Re-Advertised           3
# Ready to offer        166
# Withdrawn             162

# %%
df1 = df1[~df1.loc[:,'status'].isin(['Re-Advertised','Withdrawn','Pending'])]

# %%
df1[['ad_id','band']].groupby('band').count()
# Out:
#       ad_id
# band
# 1.0     425
# 2.0      81
# 3.0      26
# 4.0      17
