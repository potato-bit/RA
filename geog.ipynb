# %%
import pandas as pd

# %%
df = pd.read_csv('geographies.csv')

# %%
df.groupby('GeographyType').count()
# Out:
#                               GeographyID  GeographyName  \
# GeographyType
# Clinical Commissioning Group          191            191
# Combined Authority                     10             10
# Country                                 7              7
# Family Hub Reach Area                   8              8
# GP Practice                           126            126
# LSOA                                  534            534
# Local Authority                       380            380
# MSOA                                  108            108
# Output Area                          1014           1014
# Postcode                             9023           9023
# Primary Care Network                    6              6
# Region                                  9              9
# Ward                                  126            126
# West Midlands Police                    9              9
#
#                               GeographyDescription  FamilyHub   PCD  OA11  \
# ...
