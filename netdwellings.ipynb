# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('Live_Table_122.ods',header=3)
df1.head()
# Out:
#             Unnamed: 0 DCLG code FormerONS code CurrentONS code  \
# 0                  NaN       NaN            NaN             NaN
# 1              England       NaN            NaN       E92000001
# 2                  NaN       NaN            NaN             NaN
# 3  Unitary Authorities       NaN            NaN             NaN
# 4                  NaN       NaN            NaN             NaN
#
#   Met and Shire County Totals Lower and Single Tier Authority Data  \
# 0                         NaN                                  NaN
# 1                         NaN                                  NaN
# 2                         NaN                                  NaN
# 3                         NaN                                  NaN
# 4                         NaN                                  NaN
#
#    Unnamed: 6        2001-02        2002-03        2003-04  ...  \
# 0         NaN            NaN            NaN            NaN  ...
# ...

# %%
years  = list(range(2002,2022))
df1_years = df1.iloc[:,7:].copy()

# %%
df1_years.columns = years

# %%
df = df1[['CurrentONS code','Lower and Single Tier Authority Data']].copy()
for x in range(len(years)):
    df[years[x]] = df1_years[years[x]]

# %%
df.rename(columns={'CurrentONS code':'LA_code','Lower and Single Tier Authority Data':'LA'},inplace=True)

# %%
df = df[~df.loc[:,'LA'].isnull()]

# %%
df.reset_index(drop=True,inplace=True)

# %%
df = pd.melt(df,id_vars=['LA_code','LA'],var_name='year',value_name='net dwellings')

# %%
df.head()
# Out:
#      LA_code                               LA  year net dwellings
# 0  E06000022  Bath and North East Somerset UA  2002         270.4
# 1  E06000055                       Bedford UA  2002           NaN
# 2  E06000008         Blackburn with Darwen UA  2002         -73.8
# 3  E06000009                     Blackpool UA  2002         159.7
# 4  E06000028                   Bournemouth UA  2002         764.3

# %%
df[df.loc[:,'LA']=='Coventry']
# Out:
#         LA_code        LA  year net dwellings
# 117   E08000026  Coventry  2002         566.0
# 487   E08000026  Coventry  2003         624.0
# 857   E08000026  Coventry  2004          -8.0
# 1227  E08000026  Coventry  2005         308.0
# 1597  E08000026  Coventry  2006         631.0
# 1967  E08000026  Coventry  2007         918.0
# 2337  E08000026  Coventry  2008        1133.0
# 2707  E08000026  Coventry  2009         710.0
# 3077  E08000026  Coventry  2010         794.0
# 3447  E08000026  Coventry  2011         759.0
# 3817  E08000026  Coventry  2012         912.0
# 4187  E08000026  Coventry  2013         979.0
# 4557  E08000026  Coventry  2014        1089.0
# 4927  E08000026  Coventry  2015        1109.0
# 5297  E08000026  Coventry  2016        1406.0
# 5667  E08000026  Coventry  2017        1129.0
# 6037  E08000026  Coventry  2018          1095
# 6407  E08000026  Coventry  2019          1499
# 6777  E08000026  Coventry  2020          2241
# ...

# %%
df['date'] = pd.to_datetime(df['year'].astype(str),format='%Y')

# %%
df.to_excel('cleaned datasets/Net Dwellings by LA, 2001-2021.xlsx')
